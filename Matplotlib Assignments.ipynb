# %% [markdown]
# ### Q1: What is Matplotlib? Why is it used? Name five plots that can be plotted using the Pyplot module ofMatplotlib.

# %% [markdown]
# Matplotlib is a popular data visualization library in Python used for creating a wide range of static, animated, and interactive visualizations. It provides a high-level interface for creating attractive and informative charts, plots, and graphs.
#
# It is used for various purposes, including:
#
# 1. **Data Exploration:** To explore datasets and gain insights by visualizing data distributions, trends, and relationships.
# 2. **Data Presentation:** To communicate data findings effectively through visually appealing charts and graphs.
# 3. **Model Evaluation:** To assess machine learning model performance by visualizing model results and evaluation metrics.
# 4. **Scientific Plotting:** In scientific research and data analysis to visualize experimental data and research findings.
# 5. **Business Reporting:** For generating reports, dashboards, and presentations with visualized data.
#
# Five common plots that can be created using the Pyplot module of Matplotlib are:
#
# 1. **Line Plot:** Used to visualize the trend or relationship between two variables over a continuous interval.
# 2. **Scatter Plot:** Useful for displaying individual data points and exploring relationships between variables.
# 3. **Bar Chart:** Used for comparing categories or discrete data by representing them as bars.
# 4. **Histogram:** Shows the distribution of a dataset by dividing it into bins and displaying the frequency of values in each bin.
# 5. **Pie Chart:** Useful for displaying parts of a whole and showing the proportion of different categories in a dataset.

# %% [markdown]
# | Method                 | Use Cases                                   |
# |------------------------|---------------------------------------------|
# | `plt.plot()`           | Line plots, time series, trends              |
# | `plt.scatter()`        | Scatter plots, correlations, individual data points |
# | `plt.bar()`            | Bar charts, comparing categorical data       |
# | `plt.hist()`           | Histograms, distribution of data             |
# | `plt.pie()`            | Pie charts, composition of a whole           |
# | `plt.boxplot()`        | Box plots, visualizing data distribution     |
# | `plt.imshow()`         | Displaying images or heatmaps                |
# | `plt.contour()`        | Contour plots, 2D data visualization         |
# | `plt.polar()`          | Polar plots, circular data representation    |
# | `plt.errorbar()`       | Error bars, uncertainty visualization        |
# | `plt.stem()`           | Stem plots, discrete data visualization     |
# | `plt.fill_between()`   | Filled area plots, highlighting regions      |
# | `plt.stackplot()`      | Stacked area plots, multiple categories     |
# | `plt.barh()`           | Horizontal bar charts, categorical comparison |
# | `plt.hexbin()`         | Hexbin plots, bivariate data representation  |
# | `plt.quiver()`         | Quiver plots, vector field visualization    |
# | `plt.violinplot()`     | Violin plots, data distribution and density |
# | `plt.table()`          | Tables, displaying data in tabular form     |
# | `plt.subplot()`        | Subplots, multiple plots in one figure      |
# | `plt.figure()`         | Creating custom figures and layouts          |
# | `plt.colorbar()`       | Adding colorbars to plots                    |
# | `plt.text()`           | Adding text annotations to plots             |
# | `plt.annotate()`       | Annotating specific points in plots          |
#
# These methods provide a wide range of options for creating different types of visualizations in Matplotlib, from basic line plots to more complex charts and figures. Choose the appropriate method based on your data and visualization goals.

# %% [markdown]
# ### Q2: What is a scatter plot? Use the following code to generate data for x and y. Using this generated data
# plot a scatter plot.
# import numpy as np
# np.random.seed(3)
# x = 3 + np.random.normal(0, 2, 50)
# y = 3 + np.random.normal(0, 2, len(x))
# Note: Also add title, xlabel, and ylabel to the plot.

# %%
import matplotlib.pyplot as plt
import numpy as np

# Generate random data
np.random.seed(3)
x = 3 + np.random.normal(0, 2, 50)
y = 3 + np.random.normal(0, 2, len(x))

# Create a scatter plot
plt.scatter(x, y, c='blue', marker='o', label='Data Points')

# Add title, xlabel, and ylabel
plt.title('Scatter Plot Example')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')

# Display the legend
plt.legend()

# Show the plot
plt.show()

# %% [markdown]
# ### Q3: Why is the subplot() function used? Draw four line plots using the subplot() function.Use the following data:
# import numpy as np
# For line 1: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([0, 100, 200, 300, 400, 500])
# For line 2: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([50, 20, 40, 20, 60, 70])
# For line 3: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([10, 20, 30, 40, 50, 60])
# For line 4: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([200, 350, 250, 550, 450, 150])

# %%
# Data for line plots
x1 = np.array([0, 1, 2, 3, 4, 5])
y1 = np.array([0, 100, 200, 300, 400, 500])

x2 = np.array([0, 1, 2, 3, 4, 5])
y2 = np.array([50, 20, 40, 20, 60, 70])

x3 = np.array([0, 1, 2, 3, 4, 5])
y3 = np.array([10, 20, 30, 40, 50, 60])

x4 = np.array([0, 1, 2, 3, 4, 5])
y4 = np.array([200, 350, 250, 550, 450, 150])

# Create subplots
plt.figure(figsize=(12, 8))

# Subplot 1
plt.subplot(2, 2, 1)  # 2 rows, 2 columns, 1st subplot
plt.plot(x1, y1)
plt.title('Line Plot 1')

# Subplot 2
plt.subplot(2, 2, 2)  # 2 rows, 2 columns, 2nd subplot
plt.plot(x2, y2)
plt.title('Line Plot 2')

# Subplot 3
plt.subplot(2, 2, 3)  # 2 rows, 2 columns, 3rd subplot
plt.plot(x3, y3)
plt.title('Line Plot 3')

# Subplot 4
plt.subplot(2, 2, 4)  # 2 rows, 2 columns, 4th subplot
plt.plot(x4, y4)
plt.title('Line Plot 4')

# Adjust layout
plt.tight_layout()

# Show the plot
plt.show()

# %% [markdown]
# ### Q4: What is a bar plot? Why is it used? Using the following data plot a bar plot and a horizontal bar plot.
# import numpy as np
# company = np.array(["Apple", "Microsoft", "Google", "AMD"])
# profit = np.array([3000, 8000, 1000, 10000])

# %% [markdown]
# A bar plot (or bar chart) is a graphical representation of categorical data with rectangular bars. Each bar has a length or height proportional to the values they represent, making it a useful visualization for comparing different categories or groups. Bar plots are used to display and compare the values of different categories or to track changes over time.

# %%
# Data
company = np.array(["Apple", "Microsoft", "Google", "AMD"])
profit = np.array([3000, 8000, 1000, 10000])

# Create a vertical bar plot
plt.figure(figsize=(8, 6))
plt.bar(company, profit, color='skyblue')
plt.xlabel('Company')
plt.ylabel('Profit (in billions)')
plt.title('Company Profits')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# Create a horizontal bar plot
plt.figure(figsize=(8, 6))
plt.barh(company, profit, color='lightcoral')
plt.xlabel('Profit (in billions)')
plt.ylabel('Company')
plt.title('Company Profits')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Q5: What is a box plot? Why is it used? Using the following data plot a box plot.
# box1 = np.random.normal(100, 10, 200)
# box2 = np.random.normal(90, 20, 200)

# %%
# Data
box1 = np.random.normal(100, 10, 200)
box2 = np.random.normal(90, 20, 200)

# Create a figure and axis
fig, ax = plt.subplots()

# Create a box plot
data = [box1, box2]
ax.boxplot(data, vert=False, labels=['Box 1', 'Box 2'])
ax.set_xlabel('Value')
ax.set_title('Box Plot')

plt.show()
